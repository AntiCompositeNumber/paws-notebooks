# %%
from collections import namedtuple
import re
import requests
import pywikibot
import mwparserfromhell
import wikiwho_wrapper
import WikiWho

site = pywikibot.Site('en', 'wikipedia')

search = 'cite%20note'
FakeRef = namedtuple('FakeRef', ['page', 'num', 'name', 'text', 'diff'])

# %%
def find_fake_refs(page_text):
    wikicode = mwparserfromhell.parse(page_text)
    fake_refs = wikicode.ifilter_wikilinks(matches='#cite%20note')
    return fake_refs

# %%
def parse_fake_ref(fake_ref_text):
    m = regex = r'\[\[(.*)#cite%20note(?:-(.*))?-(.*)\|\[(\d*)\]\]'
    
    if m[3] != m[4]: raise ValueError
    
    fake_ref = FakeRef(
        page = m[1],
        num = m[4],
        name = m[2],
        text = fake_ref_text,
        diff = get_creation_revision(m[1], fake_ref_text)
    )
    return fake_ref

# %%
def get_creation_revision(page_title, search_text):
    page = pywikibot.Page(site, page_title)
    
    def lin_search():
        for rev in page.revisions(content=Yes, total=50):
            if re.search(search_text, rev.text):
                
        
    
    return response

# %%
def find_correct_ref():

# %%
search_results = site.search(f'insource:"{search}"', namespace=0)

for page in search_results:

# %% [markdown]
# ### Licensing
# Copyright 2019 AntiCompositeNumber
#
# Licensed under the Apache License, Version 2.0 (the "License"); you may not use this file except in compliance with the License. You may obtain a copy of the License at
#
#   http://www.apache.org/licenses/LICENSE-2.0
#
# Unless required by applicable law or agreed to in writing, software distributed under the License is distributed on an "AS IS" BASIS, WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied. See the License for the specific language governing permissions and limitations under the License.
#
# ### To fork:
# 1. Open the [raw page](?format=raw) and save it to your computer
# 2. Go to your [PAWS control panel](https://paws.wmflabs.org/paws/hub) and sign in using OAUTH
# 3. Click Upload and upload the file from step 1
# 4. To run, open the notebook and click Cell > Run All

# %%
page = pywikibot.Page(site, 'University of California, Berkeley')

fake_refs = find_fake_refs(page.text)

fr_list = list(fake_refs)
for ref in fr_list:
    print(ref)
# Out:
# [[University of California, Berkeley#cite%20note-26|[26]]
# [[University of California, Berkeley#cite%20note-27|[27]]
# [[University of California, Berkeley#cite%20note-USNWR%20Overall2-28|[28]]
# [[University of California, Berkeley#cite%20note-Times%20Rep-29|[29]]

# %%
get_creation_revision('University of California, Berkeley', 'foo')
# Out:
# {'article_title': 'University_of_California,_Berkeley',
#  'page_id': 31922,
#  'success': True,
#  'message': None,
#  'threshold': 0,
#  'all_tokens': [{'str': 'the',
#    'o_rev_id': 291754,
#    'editor': '0|130.236.221.xxx',
#    'token_id': 0},
#   {'str': 'university',
#    'o_rev_id': 291754,
#    'editor': '0|130.236.221.xxx',
#    'token_id': 1},
#   {'str': 'of',
#    'o_rev_id': 291754,
#    'editor': '0|130.236.221.xxx',
#    'token_id': 2},
#   {'str': 'california',
#    'o_rev_id': 291754,
#    'editor': '0|130.236.221.xxx',
#    'token_id': 3},
#   {'str': 'at',
#    'o_rev_id': 291754,
#    'editor': '0|130.236.221.xxx',
#    'token_id': 4},
#   {'str': 'berkeley',
#    'o_rev_id': 291754,
#    'editor': '0|130.236.221.xxx',
#    'token_id': 5},
#   {'str': '(',
#    'o_rev_id': 291754,
#    'editor': '0|130.236.221.xxx',
#    'token_id': 6},
#   {'str': 'ucb',
#    'o_rev_id': 291754,
#    'editor': '0|130.236.221.xxx',
#    'token_id': 7},
#   {'str': ')',
# ...

# %%
wikc = '[[University of California, Berkeley#cite%20note-USNWR%20Overall2-28|[28]]'
WikiWho.utils.split_into_tokens(wikc)[0]
# Out:
# '[['

# %%
if bool(re.search("g", "abcdef")):
    print('True')

# %%
page = pywikibot.Page(site, 'University of California, Berkeley')
text = '[[University of California, Berkeley#cite%20note-USNWR%20Overall2-28|[28]]'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /srv/paws/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378                 # Python 2.7, use buffering of HTTP responses
# --> 379                 httplib_response = conn.getresponse(buffering=True)
#     380             except TypeError:
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-81-cde7f92c9c0e> in <module>
#       1 page = pywikibot.Page(site, 'University of California, Berkeley')
#       2 site.loadrevisions(page, total=10)
# ----> 3 print(page.revisions())
#
# /srv/paws/pwb/pywikibot/tools/__init__.py in wrapper(*__args, **__kw)
# ...

# %%
def genny():
    for 

g = genny()
next(g)
# Out:
# 1
